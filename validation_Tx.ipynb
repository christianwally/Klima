# %%
import xarray as xr
import pickle 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from eofs.multivariate.iris import MultivariateEof
import iris
import datetime

rmse90 = pickle.load( open( "rmse90_Tx.p", "rb" ) )
rmse80_no_r = pickle.load( open( "rmse80_Tx_no_r.p", "rb" ) )
rmse80 = pickle.load( open( "rmse80_Tx.p", "rb" ) )

dti = pd.date_range('1979-01-01', periods=len(rmse90), freq='D')
a = pd.DataFrame(dti,columns=['time'])
a['day_of_year'] = a['time'].dt.dayofyear
a['rmse80']=rmse80
a['rmse90']=rmse90
a['rmse80_no_r']=rmse80_no_r

# %%
# %matplotlib notebook
a.groupby('day_of_year')['rmse90','rmse80','rmse80_no_r'].mean().plot()
plt.xticks(np.linspace(0,365,13)[:-1], ('Jan', 'Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov', 'Dec'))
plt.xlabel('month'),plt.ylabel('mittl. RMSE'),plt.title('jahreszeitlicher Verlauf des RMSE')
plt.grid()
#plt.plot(a['rmse90'][9497:9861].values)
# Out:
# <img src="data:image/png;base64,..." width="969">

# %%
a['year'] = a['time'].dt.year
a.groupby('year')['rmse90','rmse80','rmse80_no_r'].mean().plot()
plt.xlabel('month'),plt.ylabel('mittl. RMSE'),plt.title('Verlauf des RMSE (Jahresmittel)')
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a['rmse90'].mean()
# Out:
# 1222.4873345942246

# %%
a['rmse80_no_r'].mean()
# Out:
# 1272.0392898185357

# %%
rmse90 = pickle.load( open( "rmse90_RR.p", "rb" ) )
rmse80_no_r = pickle.load( open( "rmse80_no_r_RR.p", "rb" ) )
rmse80 = pickle.load( open( "rmse80_RR.p", "rb" ) )

dti = pd.date_range('1979-01-01', periods=len(rmse90), freq='D')
b = pd.DataFrame(dti,columns=['time'])
b['day_of_year'] = b['time'].dt.dayofyear
b['rmse80']=rmse80
b['rmse90']=rmse90
b['rmse80_no_r']=rmse80_no_r

b.groupby('day_of_year')['rmse90','rmse80','rmse80_no_r'].mean().plot()
plt.xticks(np.linspace(0,365,13)[:-1], ('Jan', 'Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov', 'Dec'))
plt.xlabel('month'),plt.ylabel('mittl. RMSE'),plt.title('jahreszeitlicher Verlauf des RMSE')
plt.grid()
#plt.plot(a['rmse90'][9497:9861].values)
# Out:
# <img src="data:image/png;base64,..." width="963">

# %%
b['year'] = a['time'].dt.year

b.groupby('year')['rmse90','rmse80','rmse80_no_r'].mean().plot()

plt.xlabel('month'),plt.ylabel('mittl. RMSE'),plt.title('Verlauf des RMSE (Jahresmittel)')

plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="969.5">
